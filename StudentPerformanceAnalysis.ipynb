# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarpattnaik8080/StudentResultAnalysis/blob/main/StudentPerformanceAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("stddata.csv")

# %%
df
# Out:
#      Study Hours  Previous Exam Score  Pass/Fail
# 0       4.370861            81.889703          0
# 1       9.556429            72.165782          1
# 2       7.587945            58.571657          0
# 3       6.387926            88.827701          1
# 4       2.404168            81.083870          0
# ..           ...                  ...        ...
# 495     4.180170            45.494924          0
# 496     6.252905            95.038815          1
# 497     1.699612            48.209118          0
# 498     9.769553            97.014241          1
# 499     9.875897            66.760346          1
#
# [500 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Study Hours'].plot(kind='hist', bins=20, title='Study Hours')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
df.head()
# Out:
#    Study Hours  Previous Exam Score  Pass/Fail
# 0     4.370861            81.889703          0
# 1     9.556429            72.165782          1
# 2     7.587945            58.571657          0
# 3     6.387926            88.827701          1
# 4     2.404168            81.083870          0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Study Hours'].plot(kind='hist', bins=20, title='Study Hours')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Previous Exam Score'].plot(kind='hist', bins=20, title='Previous Exam Score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Pass/Fail'].plot(kind='hist', bins=20, title='Pass/Fail')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
#from the above observation we can assume that guy with less study hour performs better as compared to guy who reads 9+ hours so an assumption can be made that hes not focussed

# %%
df.describe()
# Out:
#        Study Hours  Previous Exam Score   Pass/Fail
# count   500.000000           500.000000  500.000000
# mean      5.487055            68.917084    0.368000
# std       2.688196            17.129607    0.482744
# min       1.045554            40.277921    0.000000
# 25%       3.171517            53.745955    0.000000
# 50%       5.618474            68.309294    0.000000
# 75%       7.805124            83.580209    1.000000
# max       9.936683            99.983060    1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['Study Hours'].plot(kind='hist', bins=20, title='Study Hours')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['Previous Exam Score'].plot(kind='hist', bins=20, title='Previous Exam Score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df.info() #to know the datatype inside the column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Study Hours          500 non-null    float64
#  1   Previous Exam Score  500 non-null    float64
#  2   Pass/Fail            500 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 11.8 KB

# %%
#charts for no of hours

# %%
ax=sns.countplot(data=df,x="Study Hours")
ax.bar_label(ax.containers[0])
plt.show()

# %%
#chart for impact of number of hours studying with their marks scored
gb=df.groupby("Study Hours").agg({"Previous Exam Score":'mean'})

# %%
gb
# Out:
#              Previous Exam Score
# Study Hours
# 1.045554               55.278439
# 1.049699               63.792567
# 1.062569               42.200992
# 1.082773               99.397614
# 1.097539               60.509041
# ...                          ...
# 9.879756               73.250680
# 9.881982               60.895328
# 9.910485               58.703324
# 9.914546               83.336016
# 9.936683               55.735843
#
# [500 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# gb['Previous Exam Score'].plot(kind='hist', bins=20, title='Previous Exam Score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...
